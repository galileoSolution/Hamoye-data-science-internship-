# %%
# import libraries

import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
# Read datasets
data  = pd.read_csv("energydata_complete.csv")

# %%
data.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %% [markdown]
# # EDA

# %%
data.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
data.shape
# Out:
# (19735, 29)

# %%
# unique count check
feats = [f for f in data.columns if f not in ['record_id']]
for i in feats:
    print ('==' + str(i) + '==')
    print ('data:' + str(data[i].nunique()/data.shape[0]))
# Out:
# ==date==
# data:1.0
# ==Appliances==
# data:0.004661768431720294
# ==lights==
# data:0.0004053711679756777
# ==T1==
# data:0.03658474790980491
# ==RH_1==
# data:0.1290600456042564
# ==T2==
# data:0.08360780339498353
# ==RH_2==
# data:0.171066632885736
# ==T3==
# data:0.07225741069166455
# ==RH_3==
# data:0.13265771472004054
# ==T4==
# data:0.07043324043577401
# ==RH_4==
# data:0.15135545984291868
# ==T5==
# data:0.11466936914111983
# ==RH_5==
# data:0.383633139092982
# ==T6==
# data:0.2252850266024829
# ==RH_6==
# data:0.4919685837344819
# ==T7==
# data:0.09906257917405624
# ==RH_7==
# data:0.2985051938180897
# ==T8==
# data:0.11289587028122625
# ==RH_8==
# data:0.3369141119837852
# ==T9==
# data:0.046820369901190775
# ==RH_9==
# data:0.17167468963769952
# ==T_out==
# data:0.0876615150747403
# ==Press_mm_hg==
# data:0.11091968583734482
# ==RH_out==
# data:0.028680010134279198
# ==Windspeed==
# data:0.009576893843425386
# ==Visibility==
# data:0.02092728654674436
# ==Tdewpoint==
# ...

# %%
# Distribution of mean and std

plt.figure(figsize=(16,6))
features = data[feats].columns.values
plt.title("Distribution of mean values per row in the data")
sns.distplot(data[features].mean(axis=1),color="green", kde=True,bins=120, label='data')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,6))
features = data[feats].columns.values
plt.title("Distribution of std values per row in the train and test set")
sns.distplot(data[features].std(axis=1),color="green", kde=True,bins=120, label='data')
plt.legend()
plt.show()

# %%
# Feature Correlation

correlations = data[features].corr().unstack().sort_values(kind="quicksort").reset_index()
correlations = correlations[correlations['level_0'] != correlations['level_1']]
correlations
# Out:
#     level_0 level_1         0
# 0      RH_6      T7 -0.753973
# 1        T7    RH_6 -0.753973
# 2      RH_6      T9 -0.738940
# 3        T9    RH_6 -0.738940
# 4      RH_6      T4 -0.703149
# ..      ...     ...       ...
# 751      T9      T7  0.944776
# 752   T_out      T6  0.974787
# 753      T6   T_out  0.974787
# 754     rv1     rv2  1.000000
# 770     rv2     rv1  1.000000
#
# [756 rows x 3 columns]

# %%
data.corr()
# Out:
#              Appliances    lights        T1      RH_1        T2      RH_2  \
# Appliances     1.000000  0.197278  0.055447  0.086031  0.120073 -0.060465
# lights         0.197278  1.000000 -0.023528  0.106968 -0.005622  0.050985
# T1             0.055447 -0.023528  1.000000  0.164006  0.836834 -0.002509
# RH_1           0.086031  0.106968  0.164006  1.000000  0.269839  0.797535
# T2             0.120073 -0.005622  0.836834  0.269839  1.000000 -0.165610
# RH_2          -0.060465  0.050985 -0.002509  0.797535 -0.165610  1.000000
# T3             0.085060 -0.097393  0.892402  0.253230  0.735245  0.137319
# RH_3           0.036292  0.131161 -0.028550  0.844677  0.121497  0.678326
# T4             0.040281 -0.008859  0.877001  0.106180  0.762066 -0.047304
# RH_4           0.016965  0.114936  0.097861  0.880359  0.231563  0.721435
# T5             0.019760 -0.078745  0.885247  0.205797  0.720550  0.110409
# RH_5           0.006955  0.141233 -0.014782  0.303258  0.029595  0.250271
# ...

# %%
# sns.pairplot(data)

# %%
data.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
data.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
X = data.T2.values.reshape(-1,1)
y = data.T6

# %%
y
# Out:
# 0         7.026667
# 1         6.833333
# 2         6.560000
# 3         6.433333
# 4         6.366667
#            ...
# 19730    24.796667
# 19731    24.196667
# 19732    23.626667
# 19733    22.433333
# 19734    21.026667
# Name: T6, Length: 19735, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred  = model.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error

# %%
r2_score(y_test,pred)
# Out:
# 0.6427789637197382

# %%
mean_absolute_error(y_test,pred)
# Out:
# 2.8229401131313034

# %%
model.score(X_test, y_test)
# Out:
# 0.6427789637197382

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc  = MinMaxScaler()

# %%
# Read datasets
data  = pd.read_csv("energydata_complete.csv")

# %%
data[(data.drop(["date",'lights'], axis   =1)).columns] = sc.fit_transform(data.drop(["date",'lights'], axis   =1))

# %%
data.head()
# Out:
#                   date  Appliances  lights       T1      RH_1        T2  \
# 0  2016-01-11 17:00:00    0.046729      30  0.32735  0.566187  0.225345
# 1  2016-01-11 17:10:00    0.046729      30  0.32735  0.541326  0.225345
# 2  2016-01-11 17:20:00    0.037383      30  0.32735  0.530502  0.225345
# 3  2016-01-11 17:30:00    0.037383      40  0.32735  0.524080  0.225345
# 4  2016-01-11 17:40:00    0.046729      40  0.32735  0.531419  0.225345
#
#        RH_2        T3      RH_3        T4  ...        T9      RH_9     T_out  \
# 0  0.684038  0.215188  0.746066  0.351351  ...  0.223032  0.677290  0.372990
# 1  0.682140  0.215188  0.748871  0.351351  ...  0.226500  0.678532  0.369239
# 2  0.679445  0.215188  0.755569  0.344745  ...  0.219563  0.676049  0.365488
# 3  0.678414  0.215188  0.758685  0.341441  ...  0.219563  0.671909  0.361736
# 4  0.676727  0.215188  0.758685  0.341441  ...  0.219563  0.671909  0.357985
#
# ...

# %%
X= data.drop(["Appliances","date",'lights'], axis   =1)
y  = data.Appliances

# %%
X.head()
# Out:
#         T1      RH_1        T2      RH_2        T3      RH_3        T4  \
# 0  0.32735  0.566187  0.225345  0.684038  0.215188  0.746066  0.351351
# 1  0.32735  0.541326  0.225345  0.682140  0.215188  0.748871  0.351351
# 2  0.32735  0.530502  0.225345  0.679445  0.215188  0.755569  0.344745
# 3  0.32735  0.524080  0.225345  0.678414  0.215188  0.758685  0.341441
# 4  0.32735  0.531419  0.225345  0.676727  0.215188  0.758685  0.341441
#
#        RH_4        T5      RH_5  ...        T9      RH_9     T_out  \
# 0  0.764262  0.175506  0.381691  ...  0.223032  0.677290  0.372990
# 1  0.782437  0.175506  0.381691  ...  0.226500  0.678532  0.369239
# 2  0.778062  0.175506  0.380037  ...  0.219563  0.676049  0.365488
# 3  0.770949  0.175506  0.380037  ...  0.219563  0.671909  0.361736
# 4  0.762697  0.178691  0.380037  ...  0.219563  0.671909  0.357985
#
#    Press_mm_hg    RH_out  Windspeed  Visibility  Tdewpoint       rv1       rv2
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred  = model.predict(X_test)

# %%
mean_absolute_error(y_test,pred)
# Out:
# 0.05013362397742955

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(y_test,pred))
# Out:
# 0.0875144494766171

# %%
np.sum(np.square(y_test-pred))# residual sum of squares
# Out:
# 45.34762967266377

# %%
r2_score(y_test,pred)
# Out:
# 0.14890246319303535

# %%
#comparing the effects of regularisation
def get_weights_df(model, feat, col_name):
    #this function returns the weight of every feature
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    return weights_df

# %%
lm = get_weights_df(model, X_train, 'Linear_Model_Weight')
lm
# Out:
#        Features  Linear_Model_Weight
# 0          RH_2            -0.456698
# 1         T_out            -0.321860
# 2            T2            -0.236178
# 3            T9            -0.189941
# 4          RH_8            -0.157595
# 5        RH_out            -0.077671
# 6          RH_7            -0.044614
# 7          RH_9            -0.039800
# 8            T5            -0.015657
# 9            T1            -0.003281
# 10          rv2             0.000770
# 11          rv1             0.000770
# 12  Press_mm_hg             0.006839
# 13           T7             0.010319
# 14   Visibility             0.012307
# 15         RH_5             0.016006
# 16         RH_4             0.026386
# 17           T4             0.028981
# 18    Windspeed             0.029183
# 19         RH_6             0.038049
# 20         RH_3             0.096048
# 21           T8             0.101995
# 22    Tdewpoint             0.117758
# 23           T6             0.236425
# ...

# %%
lm[lm.Linear_Model_Weight ==lm.Linear_Model_Weight.min()]
# Out:
#   Features  Linear_Model_Weight
# 0     RH_2            -0.456698

# %%
lm[lm.Linear_Model_Weight ==lm.Linear_Model_Weight.max()]
# Out:
#    Features  Linear_Model_Weight
# 25     RH_1             0.553547

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.4)

# %%
pred = ridge_reg.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test,pred))
# Out:
# 0.08753385704628003

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.001)

# %%
pred= lasso_reg.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test,pred))
# Out:
# 0.09358170467245137

# %%
lm = get_weights_df(lasso_reg, X_train, 'Linear_Model_Weight')
lm
# Out:
#        Features  Linear_Model_Weight
# 0        RH_out            -0.049557
# 1          RH_8            -0.000110
# 2            T1             0.000000
# 3     Tdewpoint             0.000000
# 4    Visibility             0.000000
# 5   Press_mm_hg            -0.000000
# 6         T_out             0.000000
# 7          RH_9            -0.000000
# 8            T9            -0.000000
# 9            T8             0.000000
# 10         RH_7            -0.000000
# 11          rv1            -0.000000
# 12           T7            -0.000000
# 13           T6             0.000000
# 14         RH_5             0.000000
# 15           T5            -0.000000
# 16         RH_4             0.000000
# 17           T4            -0.000000
# 18         RH_3             0.000000
# 19           T3             0.000000
# 20         RH_2            -0.000000
# 21           T2             0.000000
# 22         RH_6            -0.000000
# 23          rv2            -0.000000
# ...
